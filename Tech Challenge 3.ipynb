# %%
# !pip install "numpy<2" pyspark

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
os.environ["PYARROW_IGNORE_TIMEZONE"] = "1"
print(np.__version__)
# Out:
# 1.26.4

# %%
# Carregando o Spark
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("spark") \
    .getOrCreate()

# %%
# Carregando o Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Carregando dados
df_oct_2019= spark.read.parquet('/content/gdrive/MyDrive/oct_2019.parquet')

# %%
# Visualizar DF
df_oct_2019.show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|   brand|  price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# |2019-10-01 00:00:...|      view|  44600062|2103807459595387724|                NULL|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 00:00:...|      view|   3900821|2053013552326770905|appliances.enviro...|    aqua|   33.2|554748717|9333dfbd-b87a-470...|
# |2019-10-01 00:00:...|      view|  17200506|2053013559792632471|furniture.living_...|    NULL|  543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:00:...|      view|   1307067|2053013558920217191|  computers.notebook|  lenovo| 251.74|550050854|7c90fc70-0e80-459...|
# |2019-10-01 00:00:...|      view|   1004237|2053013555631882655|electronics.smart...|   apple|1081.98|535871217|c6bd7419-2748-4c5...|
# |2019-10-01 00:00:...|      view|   1480613|2053013561092866779|   computers.desktop|  pulser| 908.62|512742880|0d0d91c2-c9c2-4e8...|
# |2019-10-01 00:00:...|      view|  17300353|2053013553853497655|                NULL|   creed| 380.96|555447699|4fe811e9-91de-46d...|
# |2019-10-01 00:00:...|      view|  31500053|2053013558031024687|                NULL|luminarc|  41.16|550978835|6280d577-25c8-414...|
# |2019-10-01 00:00:...|      view|  28719074|2053013565480109009|  apparel.shoes.keds|   baden| 102.71|520571932|ac1cd4e5-a3ce-422...|
# |2019-10-01 00:00:...|      view|   1004545|2053013555631882655|electronics.smart...|  huawei| 566.01|537918940|406c46ed-90a4-478...|
# |2019-10-01 00:00:...|      view|   2900536|2053013554776244595|appliances.kitche...|elenberg|  51.46|555158050|b5bdd0b3-4ca2-4c5...|
# |2019-10-01 00:00:...|      view|   1005011|2053013555631882655|electronics.smart...| samsung| 900.64|530282093|50a293fb-5940-41b...|
# |2019-10-01 00:00:...|      view|   3900746|2053013552326770905|appliances.enviro...|   haier| 102.38|555444559|98b88fa0-d8fa-4b9...|
# |2019-10-01 00:00:...|      view|  44600062|2103807459595387724|                NULL|shiseido|  35.79|541312140|72d76fde-8bb3-4e0...|
# |2019-10-01 00:00:...|      view|  13500240|2053013557099889147|furniture.bedroom...|     brw|  93.18|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL|    NULL| 357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:00:...|      view|   1801995|2053013554415534427|electronics.video.tv|   haier| 193.03|537192226|e3151795-c355-4ef...|
# |2019-10-01 00:00:...|      view|  10900029|2053013555069845885|appliances.kitche...|   bosch|  58.95|519528062|901b9e3c-3f8f-414...|
# |2019-10-01 00:00:...|      view|   1306631|2053013558920217191|  computers.notebook|      hp| 580.89|550050854|7c90fc70-0e80-459...|
# |2019-10-01 00:00:...|      view|   1005135|2053013555631882655|electronics.smart...|   apple|1747.79|535871217|c6bd7419-2748-4c5...|
# +--------------------+----------+----------+-------------------+--------------------+--------+-------+---------+--------------------+
# only showing top 20 rows

# %%
df_oct_2019.count()
# Out:
# 42448762

# %%
# Observar o schema de dados
df_oct_2019.printSchema()
# Out:
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: long (nullable = true)
#  |-- category_id: long (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: double (nullable = true)
#  |-- user_id: long (nullable = true)
#  |-- user_session: string (nullable = true)

# %% [markdown]
# # Funções Uteis

# %%
from pyspark.sql.functions import col, coalesce

# %%
# Retorna valores nulos
def nulos(df):
  nulos= {}
  for coluna in df.columns:
    nulos[coluna]= df.filter(col(coluna).isNull()).count()
  return nulos

# %%
# Exemplo filtro
#df_oct_2019.filter(
#    (col("brand").isNotNull()) &
#    (col("product_id") == 17200506)
#).count()

# %% [markdown]
# # Tratando os dados

# %%
# Verificando nulos
dic_nulos= nulos(df_oct_2019)
dic_nulos
# Out:
# {'event_time': 0,
#  'event_type': 0,
#  'product_id': 0,
#  'category_id': 0,
#  'category_code': 13515609,
#  'brand': 6117080,
#  'price': 0,
#  'user_id': 0,
#  'user_session': 2}

# %%
# Percentual nulos x dataset
print(f'category_code: {round((dic_nulos["category_code"]/df_oct_2019.count()) * 100,3)}%')
print(f'brand: {round((dic_nulos["brand"]/df_oct_2019.count()) * 100,3)}%')
print(f'user_session: {round((dic_nulos["user_session"]/df_oct_2019.count()) * 100,6)}%')
# Out:
# category_code: 31.84%
# brand: 14.411%
# user_session: 5e-06%

# %% [markdown]
# # Coluna user_session

# %%
# Explorando user_session nulos
df_oct_2019.filter(col("user_session").isNull()).show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+-------+------+---------+------------+
# |          event_time|event_type|product_id|        category_id|       category_code|  brand| price|  user_id|user_session|
# +--------------------+----------+----------+-------------------+--------------------+-------+------+---------+------------+
# |2019-10-06 14:26:...|      cart|   1801723|2053013554415534427|electronics.video.tv|    tcl|135.65|557388939|        NULL|
# |2019-10-25 10:36:...|      cart|   1004767|2053013555631882655|electronics.smart...|samsung|246.52|549825742|        NULL|
# +--------------------+----------+----------+-------------------+--------------------+-------+------+---------+------------+

# %%
# Excluindo user_session (poucos registros; irrelevantes)
df_oct_2019= df_oct_2019.filter(col("user_session").isNotNull())
df_oct_2019.filter(col("user_session").isNull()).show()
# Out:
# +----------+----------+----------+-----------+-------------+-----+-----+-------+------------+
# |event_time|event_type|product_id|category_id|category_code|brand|price|user_id|user_session|
# +----------+----------+----------+-----------+-------------+-----+-----+-------+------------+
# +----------+----------+----------+-----------+-------------+-----+-----+-------+------------+

# %%
# Verificando nulos
dic_nulos= nulos(df_oct_2019)
dic_nulos
# Out:
# {'event_time': 0,
#  'event_type': 0,
#  'product_id': 0,
#  'category_id': 0,
#  'category_code': 13515609,
#  'brand': 6117080,
#  'price': 0,
#  'user_id': 0,
#  'user_session': 0}

# %% [markdown]
# # Coluna brand

# %%
# Explorando brand nulos
df_oct_2019.filter(col("brand").isNull()).show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|brand| price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |2019-10-01 00:00:...|      view|  17200506|2053013559792632471|furniture.living_...| NULL| 543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL| NULL|357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:00:...|      view|  34700031|2061717937420501730|                NULL| NULL|151.87|539512263|f27a45f8-fb98-459...|
# |2019-10-01 00:00:...|      view|  13500046|2053013557099889147|furniture.bedroom...| NULL| 60.75|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:00:...|      view|  31501072|2053013558031024687|                NULL| NULL|165.64|550978835|6280d577-25c8-414...|
# |2019-10-01 00:00:...|      view|  28600026|2053013558282682943|                NULL| NULL|399.73|555447224|889da81c-2cfc-4df...|
# |2019-10-01 00:00:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:00:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|555447748|b50d1ae8-1948-451...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL| NULL|357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:01:...|      view|  15100337|2053013557024391671|                NULL| NULL|257.15|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:01:...|      view|  34700023|2061717937420501730|                NULL| NULL| 109.4|539512263|f27a45f8-fb98-459...|
# |2019-10-01 00:01:...|      view|  26200210|2053013563693335403|                NULL| NULL| 98.84|555447493|8c3e1835-2196-402...|
# |2019-10-01 00:01:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  26201858|2053013563693335403|                NULL| NULL|235.01|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  17200142|2053013559792632471|furniture.living_...| NULL| 543.1|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:02:...|      view|  29800033|2053013559842964121|furniture.living_...| NULL|169.86|555306597|3a374230-2ac7-429...|
# |2019-10-01 00:02:...|      view|  26201858|2053013563693335403|                NULL| NULL|235.01|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  21402696|2053013561579406073|  electronics.clocks| NULL| 24.97|525856698|f72ea16b-4ec3-44f...|
# |2019-10-01 00:02:...|      view|   3500093|2053013555287949705|                NULL| NULL| 33.46|539979421|613162b2-7159-400...|
# |2019-10-01 00:02:...|      view|  50600002|2134905044833666047|auto.accessories....| NULL| 89.81|514933060|2f36c9e1-b1e1-4b5...|
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Observações
# A coluna product_id representa o id do produto e não há valores nulos para esta coluna.
#
# Será que o product_id x não se repete tanto para casos onde a coluna brand está preenchida ou não?
#
# Usando product_id, podemos obter parte da marca para os casos onde esta informação não está preenchida em brand.

# %%
# Obtendo dataset onde a marca não é preenchida
df_brand_null= df_oct_2019.filter((col("brand").isNull()))
df_brand_null.show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|brand| price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# |2019-10-01 00:00:...|      view|  17200506|2053013559792632471|furniture.living_...| NULL| 543.1|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL| NULL|357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:00:...|      view|  34700031|2061717937420501730|                NULL| NULL|151.87|539512263|f27a45f8-fb98-459...|
# |2019-10-01 00:00:...|      view|  13500046|2053013557099889147|furniture.bedroom...| NULL| 60.75|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:00:...|      view|  31501072|2053013558031024687|                NULL| NULL|165.64|550978835|6280d577-25c8-414...|
# |2019-10-01 00:00:...|      view|  28600026|2053013558282682943|                NULL| NULL|399.73|555447224|889da81c-2cfc-4df...|
# |2019-10-01 00:00:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:00:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|555447748|b50d1ae8-1948-451...|
# |2019-10-01 00:00:...|      view|  23100006|2053013561638126333|                NULL| NULL|357.79|513642368|17566c27-0a8f-450...|
# |2019-10-01 00:01:...|      view|  15100337|2053013557024391671|                NULL| NULL|257.15|519107250|566511c2-e2e3-422...|
# |2019-10-01 00:01:...|      view|  34700023|2061717937420501730|                NULL| NULL| 109.4|539512263|f27a45f8-fb98-459...|
# |2019-10-01 00:01:...|      view|  26200210|2053013563693335403|                NULL| NULL| 98.84|555447493|8c3e1835-2196-402...|
# |2019-10-01 00:01:...|      view|  26200591|2053013563693335403|                NULL| NULL|203.35|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  26201858|2053013563693335403|                NULL| NULL|235.01|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  17200142|2053013559792632471|furniture.living_...| NULL| 543.1|555446365|7f0062d8-ead0-4e0...|
# |2019-10-01 00:02:...|      view|  29800033|2053013559842964121|furniture.living_...| NULL|169.86|555306597|3a374230-2ac7-429...|
# |2019-10-01 00:02:...|      view|  26201858|2053013563693335403|                NULL| NULL|235.01|548449430|99617d1c-1b5a-42f...|
# |2019-10-01 00:02:...|      view|  21402696|2053013561579406073|  electronics.clocks| NULL| 24.97|525856698|f72ea16b-4ec3-44f...|
# |2019-10-01 00:02:...|      view|   3500093|2053013555287949705|                NULL| NULL| 33.46|539979421|613162b2-7159-400...|
# |2019-10-01 00:02:...|      view|  50600002|2134905044833666047|auto.accessories....| NULL| 89.81|514933060|2f36c9e1-b1e1-4b5...|
# +--------------------+----------+----------+-------------------+--------------------+-----+------+---------+--------------------+
# only showing top 20 rows

# %%
# Obtendo lista de produtos onde a marca é nula
product_id_brand_null= [row.product_id for row in df_brand_null.select("product_id").distinct().collect()]
product_id_brand_null[:5]
# Out:
# [4700630, 38900016, 28715827, 31501100, 21401936]

# %%
# Testando product_id brand null
if 17200506 in product_id_brand_null:
  print("Está na lista")
else:
  print("Não está na lista")
# Out:
# Está na lista

# %%
# Obtendo o tamanho da lista
print(f'Produtos: {len(product_id_brand_null)}')
# Out:
# Produtos: 51219

# %%
from pyspark.sql.types import StructType, StructField, IntegerType

# %%
# Criando dataframe product_id_brand_not_null
schema_ids = StructType([
    StructField("product_id", IntegerType(), False)
])
df_product_id_brand_not_null= spark.createDataFrame([(id,) for id in product_id_brand_null], schema=schema_ids)
df_product_id_brand_not_null.show()
# Out:
# +----------+
# |product_id|
# +----------+
# |   4700630|
# |  38900016|
# |  28715827|
# |  31501100|
# |  21401936|
# |  40800000|
# |  28703873|
# |  10100528|
# |  10501017|
# |  26200416|
# |  14700175|
# |  32701311|
# |  22200179|
# |  15200856|
# |  28100933|
# |   3200239|
# |   9100370|
# |  26403215|
# |  19900021|
# |  17200560|
# +----------+
# only showing top 20 rows

# %%
# Testando df_product_id_brand_not_null
linha= df_product_id_brand_not_null.filter(df_product_id_brand_not_null.product_id== 17200506).first()
linha["product_id"]
# Out:
# 17200506

# %%
# JOIN usando Spark
resultados_df = df_oct_2019.join(
    df_product_id_brand_not_null,
    "product_id", # Coluna usada para o join
    "inner"       # Tipo do join
  ).where(
    col("brand").isNotNull() # Filtra para remover marcas nulas
  ).select(
    "product_id", "brand" # Seleciona apenas as colunas que nos interessam
  ).distinct() # Adicionado para garantir resultados únicos caso hajam duplicatas

resultados_df.show()
# Out:
# +----------+---------+
# |product_id|    brand|
# +----------+---------+
# |   4502656|  samsung|
# |  12720442| cordiant|
# |  10200661|   barbie|
# |  10503794|   mattel|
# |   5600405|    braun|
# |  12719511|   viatti|
# |   2800042|  kristal|
# |  12202775|    stark|
# |   1307139|       hp|
# |  53000007|     nike|
# |  15800219|   berkut|
# |   3200302|  redmond|
# |  14100591|   madina|
# |  51200059|   norfin|
# |  25001609|  lidonet|
# |   6601076|      amd|
# |  35200094|milavitsa|
# |  31200822|     ikea|
# |  28401184|    karya|
# |  35200054|milavitsa|
# +----------+---------+
# only showing top 20 rows

# %%
# Obtendo o tamanho da lista
print(f'Produtos: {resultados_df.count()}')
# Out:
# Produtos: 7648

# %%
# Renomeia a coluna no DataFrame de lookup para evitar ambiguidade
resultados_renomeado_df = resultados_df.withColumnRenamed("brand", "brand_nova")

# LEFT JOIN para trazer as novas marcas para junto dos produtos originais
df_com_join = df_oct_2019.join(
    resultados_renomeado_df,
    on="product_id",
    how="left"
)

colunas_originais = df_oct_2019.columns

df_oct_2019_2= df_com_join.withColumn(
    "brand", # Sobrescreve a coluna 'brand' original
    coalesce(df_oct_2019.brand, col("brand_nova"))
).select(colunas_originais) # Seleciona apenas as colunas originais para manter o schema

# %%
df_oct_2019_2.show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+-------+-------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|  brand|  price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+-------+-------+---------+--------------------+
# |2019-10-01 00:00:...|      view|   1003306|2053013555631882655|electronics.smart...|  apple| 588.77|555446831|6ec635da-ea15-4a5...|
# |2019-10-29 02:11:...|      view|   1003726|2053013555631882655|electronics.smart...|   sony| 128.39|564625734|b3200271-6139-458...|
# |2019-10-04 10:59:...|      view|   1004240|2053013555631882655|electronics.smart...|  apple|1062.68|553616201|2188d4a6-10da-4ef...|
# |2019-10-17 16:34:...|      view|   1004246|2053013555631882655|electronics.smart...|  apple| 763.96|553690312|12a36156-f10d-40c...|
# |2019-10-12 19:40:...|      view|   1004321|2053013555631882655|electronics.smart...| huawei| 248.14|559593197|4622dc16-7013-483...|
# |2019-10-07 14:30:...|      view|   1004565|2053013555631882655|electronics.smart...| huawei| 169.82|557745300|b4681f0d-2780-493...|
# |2019-10-17 16:34:...|      view|   1004565|2053013555631882655|electronics.smart...| huawei| 168.81|512842634|ae0be5cd-f7ea-483...|
# |2019-10-25 18:12:...|      view|   1004565|2053013555631882655|electronics.smart...| huawei| 165.51|549540932|bc4f5f9c-2b6b-42b...|
# |2019-10-04 10:59:...|      view|   1004681|2053013555631882655|electronics.smart...| xiaomi| 171.18|527276154|56e48d48-a439-484...|
# |2019-10-25 18:12:...|      view|   1004751|2053013555631882655|electronics.smart...|samsung| 195.37|564130987|1fb23dad-0ca9-484...|
# |2019-10-25 18:12:...|      cart|   1004788|2053013555631882655|electronics.smart...| xiaomi|  136.3|543420093|c6c3a03f-6d99-4c9...|
# |2019-10-25 18:12:...|      cart|   1004788|2053013555631882655|electronics.smart...| xiaomi|  136.3|564143580|0637d8e3-1831-40e...|
# |2019-10-15 14:37:...|      view|   1004857|2053013555631882655|electronics.smart...|samsung| 130.74|512511153|62013a0f-64fe-4f1...|
# |2019-10-20 14:16:...|      view|   1004870|2053013555631882655|electronics.smart...|samsung| 284.59|516823197|c0191001-81f4-47c...|
# |2019-10-25 18:12:...|      view|   1004870|2053013555631882655|electronics.smart...|samsung| 281.51|513189407|6cdf3d04-66c5-45f...|
# |2019-10-20 14:16:...|      view|   1005007|2053013555631882655|electronics.smart...| xiaomi|  97.77|540938115|75a35d43-0aba-4a7...|
# |2019-10-17 16:34:...|      view|   1005008|2053013555631882655|electronics.smart...| xiaomi|  97.27|512733551|c4602a08-d1aa-42b...|
# |2019-10-15 14:37:...|      view|   1005167|2053013555631882655|electronics.smart...| xiaomi|  316.1|512717697|9773dfbf-3ebc-460...|
# |2019-10-25 18:12:...|      view|   1201390|2053013561059312345|  electronics.tablet|  apple|1883.05|524994298|108a8783-1399-4aa...|
# |2019-10-22 17:21:...|      view|   1480422|2053013561092866779|   computers.desktop|   acer| 308.86|546404823|283200ae-728d-4b2...|
# +--------------------+----------+----------+-------------------+--------------------+-------+-------+---------+--------------------+
# only showing top 20 rows

# %%
# Explorando brand nulos
df_oct_2019_2.filter(col("brand").isNull()).show()
# Out:
# +--------------------+----------+----------+-------------------+--------------------+-----+-----+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code|brand|price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+-----+-----+---------+--------------------+
# |2019-10-29 06:38:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|519697924|67e99dad-32a9-4d8...|
# |2019-10-29 06:46:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|543816058|3e0499c0-92ab-46d...|
# |2019-10-29 06:47:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|543816058|3e0499c0-92ab-46d...|
# |2019-10-29 06:48:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|513856670|3b8c5ffb-6670-4e9...|
# |2019-10-29 06:49:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|520443990|8bbb292e-9746-433...|
# |2019-10-29 06:52:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|489962790|728674bd-a64b-4a1...|
# |2019-10-29 07:04:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|537940501|618fb1b5-f41d-4c2...|
# |2019-10-29 07:05:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|564909201|4db9d731-b145-44b...|
# |2019-10-29 07:05:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|520254985|1eaeb23a-8c5c-464...|
# |2019-10-29 07:06:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|564909201|4db9d731-b145-44b...|
# |2019-10-29 07:06:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|547318071|65d61beb-f8d8-db7...|
# |2019-10-29 07:07:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|547318071|65d61beb-f8d8-db7...|
# |2019-10-29 07:16:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|526781189|a5cf0546-1e10-4b9...|
# |2019-10-29 07:18:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|518860071|b6a1874d-2ec1-407...|
# |2019-10-29 07:26:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|559160818|e5cba82f-bf40-405...|
# |2019-10-29 07:26:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|559160818|e5cba82f-bf40-405...|
# |2019-10-29 07:30:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|533931575|572fde0f-b2e6-420...|
# |2019-10-29 07:31:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|533931575|572fde0f-b2e6-420...|
# |2019-10-29 07:33:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|539699900|1a4b979b-3ad8-473...|
# |2019-10-29 07:39:...|      view|   1005267|2053013555631882655|electronics.smart...| NULL|  0.0|548353174|0cc1fa19-6bd5-4ca...|
# +--------------------+----------+----------+-------------------+--------------------+-----+-----+---------+--------------------+
# only showing top 20 rows

# %%
# Verificando nulos dataset novo
df_oct_2019_2.filter(col("brand").isNull()).count()
# Out:
# 5944657

# %%
# Verificando nulos (df original)
dic_nulos= nulos(df_oct_2019)
dic_nulos
# Out:
# {'event_time': 0,
#  'event_type': 0,
#  'product_id': 0,
#  'category_id': 0,
#  'category_code': 13515609,
#  'brand': 6117080,
#  'price': 0,
#  'user_id': 0,
#  'user_session': 0}

# %%
# Percentual nulos x dataset
print(f'category_code: {round((dic_nulos["category_code"]/df_oct_2019.count()) * 100,3)}%')
print(f'brand: {round((dic_nulos["brand"]/df_oct_2019.count()) * 100,3)}%')
print(f'user_session: {round((dic_nulos["user_session"]/df_oct_2019.count()) * 100,6)}%')
# Out:
# category_code: 31.84%
# brand: 14.411%
# user_session: 0.0%

# %%
# Verificando nulos (df novo)
dic_nulos= nulos(df_oct_2019_2)
dic_nulos
# Out:
# {'event_time': 0,
#  'event_type': 0,
#  'product_id': 0,
#  'category_id': 0,
#  'category_code': 13522425,
#  'brand': 5944657,
#  'price': 0,
#  'user_id': 0,
#  'user_session': 0}

# %%
# Percentual nulos x dataset novo
print(f'category_code: {round((dic_nulos["category_code"]/df_oct_2019_2.count()) * 100,3)}%')
print(f'brand: {round((dic_nulos["brand"]/df_oct_2019_2.count()) * 100,3)}%')
print(f'user_session: {round((dic_nulos["user_session"]/df_oct_2019_2.count()) * 100,6)}%')
# Out:
# category_code: 31.851%
# brand: 14.002%
# user_session: 0.0%
