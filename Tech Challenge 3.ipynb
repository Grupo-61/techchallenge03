# %% [markdown]
# # FIAP - Machine Learning Engineering - Tech Challenge 3
# # Grupo-61
#
# ## Dataset
#
#     eCommerce behavior data from multi category store
#     https://www.kaggle.com/datasets/mkechinov/ecommerce-behavior-data-from-multi-category-store/data
#
#
# **Importante**
#
#     - O dataset original encontra-se dividido em 7 partes correspondentes aos meses de Outubro/2019, Novembro/2019, Dezembro/2019, Janeiro/2020, Fevereiro/2020, Março/2020 e Abril/2020
#     - Para este cenário, o volume de dados é de 16.45 GB
#
#     Como não é requisito deste projeto trabalhar com tal volume de dados, decidimos por fazer um recorte de alguns dias de operações de e-commerce:
#
#     - Datas selecionadas: 01/12/2019, 01/01/2020, 01/02/2020, 01/03/2020 e 01-04-2020 - seleção de datas de início de mês de 6 meses da amostra, o que poderia capturar comportamentos interessantes de consumo.
#     - Com este recorte, foram extraídas 499.995 linhas e 9 colunas
#     - Para este cenário, o volume de dados é de 207.73 MB

# %% [markdown]
# ## EDA - Exploratory Data Analysis

# %%
# Importação de bibliotecas
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Para conexão com o  Google Drive (Google Colab)
# from google.colab import drive
# drive.mount('/content/drive')

# Carregando os dados (google drive)
# df = pd.read_csv('/content/drive/MyDrive/ecom_500k.csv')

# %%
# Leitura do Dataset (local)
df = pd.read_csv(r"datasets\ecom_500k.csv")

# %% [markdown]
# ### Data Understanding: Geral

# %%
# Dimensão do Dataset em linhas e colunas: aproximadamente 499.995 linhas
df.shape
# Out:
# (499995, 9)

# %%
# Visualização da 3 primeiras features
df.head(3)
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-12-01 00:00:00 UTC       view     1005105  2232732093077520756
# 1  2019-12-01 00:00:00 UTC       view    22700068  2232732091643068746
# 2  2019-12-01 00:00:01 UTC       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                           NaN  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a
# 2  5ee185a7-0689-4a33-923d-ba0130929a76

# %%
# Estrutura do dataset: features e seus tipos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499995 entries, 0 to 499994
# Data columns (total 9 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     499995 non-null  object
#  1   event_type     499995 non-null  object
#  2   product_id     499995 non-null  int64
#  3   category_id    499995 non-null  int64
#  4   category_code  447737 non-null  object
#  5   brand          428867 non-null  object
#  6   price          499995 non-null  float64
#  7   user_id        499995 non-null  int64
#  8   user_session   499995 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 34.3+ MB

# %%
# Uso de Memória
uso_memoria = df.memory_usage(deep=True).sum()
uso_memoria = uso_memoria/(1024 ** 2)
print("Uso de memória em MB:", uso_memoria)
# Out:
# Uso de memória em MB: 190.27674865722656

# %% [markdown]
# # Dicionário de Dados (CSV original)
#
# | Coluna        | Tipo de dado | Máscara / Formato                | Descrição                                                       | Exemplo                       |
# |---------------|--------------|----------------------------------|-----------------------------------------------------------------|-------------------------------|
# | event_time    | datetime     | YYYY-MM-DD HH:MM:SS              | Data e hora do evento (timestamp, geralmente UTC).               | 2025-09-28 12:34:56           |
# | event_type    | string       | texto                           | Tipo de evento: `view`, `cart`, `purchase`. | view                          |
# | product_id    | int/string   | número inteiro ou texto          | Identificador único do produto.                                  | 123456                        |
# | category_id   | int          | número inteiro                   | Identificador único da categoria.                                | 98765                         |
# | category_code | string       | texto com pontos                 | Hierarquia da categoria no formato `categoria.subcategoria`.     | electronics.smartphone        |
# | brand         | string       | texto                           | Marca do produto.                                                | Samsung                       |
# | price         | float        | ####.##                         | Preço do produto no momento do evento.                          | 1599.90                       |
# | user_id       | int          | número inteiro                   | Identificador único do usuário (anônimo).                       | 456789                        |
# | user_session  | string       | UUID ou string de sessão         | Identificador da sessão de navegação.                           | abc123-def456-ghi789          |

# %%
# Estatística Descritiva dos dados Numéricos - Evidentemente sem sentido para os ID´s, portanto, somente 'price'
df['price'].describe()
# Out:
# count    499995.000000
# mean        285.361523
# std         358.423821
# min           0.000000
# 25%          61.750000
# 50%         164.780000
# 75%         346.790000
# max        2574.070000
# Name: price, dtype: float64

# %%
# Estatística Descritiva dos dados Categóricos
df.describe(include=["object"])
# Out:
#                      event_time event_type             category_code    brand  \
# count                    499995     499995                    447737   428867
# unique                    70814          3                       137     3407
# top     2020-01-01 04:36:52 UTC       view  construction.tools.light  samsung
# freq                         74     473952                    124478    62217
#
#                                 user_session
# count                                 499995
# unique                                126462
# top     0ff295db-1fc8-46c2-8afc-03bb66c50b6c
# freq                                     275

# %%
# Quantidade de Clientes Únicos
num_users = df["user_id"].nunique()
print(num_users)
# Out:
# 98687

# %%
# Verificação de quais features tem dados Nulos (NaN)
# Observa-se dados nulos em "category_code" e "brand"
df.isnull().sum()
# Out:
# event_time           0
# event_type           0
# product_id           0
# category_id          0
# category_code    52258
# brand            71128
# price                0
# user_id              0
# user_session         0
# dtype: int64

# %% [markdown]
# ## Data Understanding e Data Preparation: product_id

# %%
# Quantidade total de produtos
df["product_id"].nunique()
# Out:
# 68727

# %%
# 10 produtos mais comprados
df[df['event_type'] == 'purchase']\
  [['product_id', 'category_id', \
    'category_code', 'brand', 'price']]\
    .value_counts().head(10)
# Out:
# product_id  category_id          category_code             brand    price
# 1004767     2232732093077520756  construction.tools.light  samsung  226.18    46
# 1004856     2232732093077520756  construction.tools.light  samsung  124.11    42
# 1005212     2232732093077520756  construction.tools.light  samsung  178.12    42
# 1005115     2232732093077520756  construction.tools.light  apple    806.61    42
# 1004767     2232732093077520756  construction.tools.light  samsung  241.83    42
# 1005115     2232732093077520756  construction.tools.light  apple    872.09    36
# 1005212     2232732093077520756  construction.tools.light  samsung  171.82    35
# 1005100     2232732093077520756  construction.tools.light  samsung  148.49    35
#                                                                     140.28    34
# 1004767     2232732093077520756  construction.tools.light  samsung  235.60    30
# Name: count, dtype: int64

# %%
# Compras product_id 1004856
df[df['event_type'] == 'purchase'][df[df['event_type'] == 'purchase']['product_id'] == 1004856]
# Out:
#                      event_time event_type  product_id          category_id  \
# 6542    2019-12-01 00:39:37 UTC   purchase     1004856  2232732093077520756
# 6733    2019-12-01 00:40:37 UTC   purchase     1004856  2232732093077520756
# 7754    2019-12-01 00:46:27 UTC   purchase     1004856  2232732093077520756
# 8213    2019-12-01 00:48:45 UTC   purchase     1004856  2232732093077520756
# 18252   2019-12-01 01:32:43 UTC   purchase     1004856  2232732093077520756
# ...                         ...        ...         ...                  ...
# 466578  2020-04-01 03:27:10 UTC   purchase     1004856  2232732093077520756
# 476019  2020-04-01 03:39:51 UTC   purchase     1004856  2232732093077520756
# 483567  2020-04-01 03:49:39 UTC   purchase     1004856  2232732093077520756
# 489832  2020-04-01 03:57:25 UTC   purchase     1004856  2232732093077520756
# 496810  2020-04-01 04:05:13 UTC   purchase     1004856  2232732093077520756
#
# ...

# %%
# 10 produtos mais vistos (populares)
df[df['event_type'] == 'view']\
  [['product_id', 'category_id', \
    'category_code', 'brand', 'price']]\
    .value_counts().head(10)
# Out:
# product_id  category_id          category_code                     brand    price
# 1004767     2232732093077520756  construction.tools.light          samsung  226.18    1895
# 16000004    2053013556856619499  accessories.bag                   rondell  43.73     1540
# 1004750     2232732093077520756  construction.tools.light          samsung  198.20    1362
# 1005115     2232732093077520756  construction.tools.light          apple    806.61    1321
# 4804718     2232732079706079299  sport.bicycle                     apple    341.06    1249
# 1005100     2232732093077520756  construction.tools.light          samsung  140.28    1088
# 1005160     2232732093077520756  construction.tools.light          xiaomi   176.90     969
# 1004767     2232732093077520756  construction.tools.light          samsung  241.83     962
#                                                                             238.54     889
# ...

# %%
# Faturamento - vendas realizadas
df[df['event_type'] == 'purchase']['price'].sum()
# Out:
# np.float64(1413787.8599999999)

# %%
# Faturamento não realizado - compras no carrinho
df[df['event_type'] == 'cart']['price'].sum()
# Out:
# np.float64(5592993.629999999)

# %%
# Produtos não faturados - compras no carrinho
df[df['event_type'] == 'cart']['product_id'].unique()
# Out:
# array([ 1004833, 17800342,  1005003, ...,  1801795,  5000755, 13105154],
#       shape=(6151,))

# %%
# Contagem de produtos não faturados segmentados por categoria
df[df['event_type'] == 'cart'][['product_id', 'category_code']].groupby('category_code').count()
# Out:
#                       product_id
# category_code
# accessories.bag              131
# accessories.umbrella           4
# accessories.wallet            48
# apparel.costume              144
# apparel.dress                  2
# ...                          ...
# sport.ski                     89
# sport.snowboard                9
# sport.tennis                  13
# sport.trainer                143
# stationery.cartrige           10
#
# [129 rows x 1 columns]

# %% [markdown]
# ## Data Understanding e Data Preparation: event_time

# %%
# Tratamento de event_time: obtenção da data do event_time, porém, também obtivemos hora e dia da semana para análises posteriores
df['event_time'] = pd.to_datetime(df['event_time'], utc=True)
df['date'] = df['event_time'].dt.date
df['hour'] = df['event_time'].dt.hour
df['weekday'] = df['event_time'].dt.day_name()   # monday, tuesday, wednesday, ...

# %%
# Quais dias (datas) foram considerados no recorte do dataset
df['date'].astype(str).unique()
# Out:
# array(['2019-12-01', '2020-01-01', '2020-02-01', '2020-03-01',
#        '2020-04-01'], dtype=object)

# %%
# Dataviz de 'date' vs. 'event_type' (quantidade de eventos, por dia)

# Agrupar por date e event_type
daily_counts = df.groupby(['date', 'event_type']).size().reset_index(name='count')

plt.figure(figsize=(12,6))
for etype in daily_counts['event_type'].unique():
    temp = daily_counts[daily_counts['event_type'] == etype]
    plt.plot(temp['date'], temp['count'], marker='o', label=etype)

plt.xlabel('Data')
plt.ylabel('Número de eventos')
plt.title('Contagem de eventos por dia e tipo de evento')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Dataviz de 'hour' vs. 'event_type' (quantidade de eventos, por hora)

# Agrupar por hour e event_type
hourly_counts = df.groupby(['hour', 'event_type']).size().reset_index(name='count')

plt.figure(figsize=(12,6))
for etype in hourly_counts['event_type'].unique():
    temp = hourly_counts[hourly_counts['event_type'] == etype]
    plt.plot(temp['hour'], temp['count'], marker='o', label=etype)

plt.xlabel('Hora do dia')
plt.ylabel('Número de eventos')
plt.title('Contagem de eventos por hora e tipo de evento (todas as datas agregadas)')
plt.legend()
plt.xticks(range(0,24))
plt.tight_layout()
plt.show()

# %%
# Dataviz de 'weekday' quantidade de eventos, por dia da semana)
df['weekday'].value_counts().reindex(
    ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
).plot(kind='bar', figsize=(10,5), title="Eventos por Dia da Semana")
# Out:
# <Axes: title={'center': 'Eventos por Dia da Semana'}, xlabel='weekday'>

# %%
# Criação de dataframe "session_time" com agrupamento por "user_session / event_time" 
session_time = df.groupby('user_session')['event_time'].agg(['min','max'])
session_time['duration'] = (session_time['max'] - session_time['min']).dt.total_seconds()/60

# Estatística Descritiva de 'duration' (Duração das Sessões)
session_time['duration'].describe()
# Out:
# count    126462.000000
# mean          7.047966
# std         482.037642
# min           0.000000
# 25%           0.000000
# 50%           0.166667
# 75%           2.816667
# max       89363.916667
# Name: duration, dtype: float64

# %%
# Separação das Sessões com Duração dentro do Percentil 95% (pode garantir equilíbrio entre precisão e segurança)
q95 = session_time['duration'].quantile(0.95)
filtered = session_time[session_time['duration'] <= q95]

# %%
# Dataviz de Distribuição da Duração das Sessões, sem Outliers (quantile=95%)
filtered['duration'].hist(bins=50, figsize=(10,5))
plt.xlabel("Duração da Sessão (minutos)")
plt.ylabel("Número de Sessões")
plt.title("Distribuição da Duração das Sessões (sem outliers)")
plt.show()

# %% [markdown]
# ## Data Understanding e Data Preparation: event_type

# %%
# Dataviz de Distribuição de Eventos por Tipo
df['event_type'].value_counts().plot(kind='bar', figsize=(8,5))
plt.xlabel("Tipo de Evento")
plt.ylabel("Número de Eventos")
plt.title("Distribuição de Eventos por Tipo")
plt.show()

# %%
# Dataviz de Funil de Vendas - Conversão
events = df['event_type'].value_counts()
conversion = events / events.sum() * 100

plt.figure(figsize=(6,6))
plt.bar(conversion.index, conversion.values)
plt.ylabel("Percentual de Eventos (%)")
plt.title("Funil de Conversão (porcentagem do total de eventos)")
plt.show()

# %%
# Dataviz de Evolução Diária dos Tipos de Eventos
df['date'] = df['event_time'].dt.date
daily_events = df.groupby(['date', 'event_type']).size().unstack()

daily_events.plot(figsize=(12,6))
plt.xlabel("Data")
plt.ylabel("Número de Eventos")
plt.title("Evolução Diária dos Tipos de Evento")
plt.show()

# %%
# Dataviz de Quantidade de Eventos, por Categoria
category_events = df.groupby(['category_code', 'event_type']).size().unstack().fillna(0)

category_events.plot(kind='bar', stacked=True, figsize=(12,6))
plt.xlabel("Categoria")
plt.ylabel("Número de Eventos")
plt.title("Eventos por Tipo de Evento em Cada Categoria")
plt.legend(title="Tipo de Evento")
plt.show()

# Observa-se que o gráfico ficou poluído! Será construída uma nova feature "main_category".

# %%
# Dataviz de Distribuição de Eventos, por Hora e Tipo
df['hour'] = df['event_time'].dt.hour
hourly_events = df.groupby(['hour', 'event_type']).size().unstack()

hourly_events.plot(kind='bar', stacked=True, figsize=(12,5))
plt.xlabel("Hora do Dia")
plt.ylabel("Número de Eventos")
plt.title("Distribuição de Eventos por Hora e Tipo")
plt.show()

# %%
# Estatística de Quantidades de Eventos, por Tipo
list(df.event_type.unique())
print(df['event_type'].value_counts())
# Out:
# event_type
# view        473952
# cart         21014
# purchase      5029
# Name: count, dtype: int64

# %% [markdown]
# ## Data Understanding e Data Preparation: category_id /category_code

# %%
# Dados nulos de category_code
df['category_code'].isnull().sum()
# Out:
# np.int64(52258)

# %%
# Dados nulos de category_id
df['category_code'].isnull().sum()
# Out:
# np.int64(52258)

# %%
# Estatística de Quantidades de Transações, por category_code
list(df.category_code.unique())
print(df['category_code'].value_counts())
# Out:
# category_code
# construction.tools.light           124478
# electronics.audio.headphone         18648
# apparel.shoes                       16921
# sport.bicycle                       16662
# appliances.personal.massager        16577
#                                     ...
# appliances.kitchen.microwave           16
# construction.tools.axe                 15
# country_yard.furniture.bench           14
# computers.components.cdrw               8
# computers.components.sound_card         7
# Name: count, Length: 137, dtype: int64

# %%
# Tratamento de category_code - Abordagem 1: preenche os valores de category_code à partir da análise do que aparece em outros product_id

# Criar dicionário product_id → category_code
prod_to_category = (
    df.dropna(subset=['category_code'])
      .drop_duplicates(subset=['product_id'])
      .set_index('product_id')['category_code']
)

# Preencher usando product_id
df['category_code'] = df.apply(
    lambda row: prod_to_category[row['product_id']] if pd.isna(row['category_code']) and row['product_id'] in prod_to_category else row['category_code'],
    axis=1
)

# %%
# Tratamento de category_code - Abordagem 2: preenche os valores de category_code à partir de brand como pista

# Criar dicionário brand → category_code mais comum
brand_to_category = (
    df.dropna(subset=['category_code'])
      .groupby('brand')['category_code']
      .agg(lambda x: x.value_counts().idxmax())
)

# Preencher os NaN com base no brand
df['category_code'] = df.apply(
    lambda row: brand_to_category[row['brand']] if pd.isna(row['category_code']) and row['brand'] in brand_to_category else row['category_code'],
    axis=1
)

# %%
# Tratamento de category_code: para o que restar de NaN, preencher com 'unknown'
df['category_code'] = df['category_code'].fillna('unknown')

# %%
# Para melhorar visualização e análises, separação ed categoria principal e subcategoria
df[['main_category','sub_category']] = df['category_code'].str.split('.', n=1, expand=True)
df.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category
# 0  construction        tools.light
# 1       apparel              shirt
# 2    appliances  personal.massager

# %%
# Estatística de Quantidades de Transações, por main_category
df['main_category'].value_counts()
# Out:
# main_category
# construction    140704
# appliances       94005
# apparel          73366
# electronics      59792
# computers        31621
# sport            28884
# furniture        28434
# unknown          15543
# kids             12419
# accessories       9312
# auto              4116
# country_yard      1024
# medicine           501
# stationery         274
# Name: count, dtype: int64

# %%
# Estatística de Quantidades de Transações, agrupadas por main_category/event_type
category_event_counts = df.groupby(['main_category', 'event_type']).size().unstack()
category_event_counts
# Out:
# event_type     cart  purchase    view
# main_category
# accessories     201        36    9075
# apparel        2444       478   70444
# appliances     3491       786   89728
# auto            115        32    3969
# computers      1328       223   30070
# construction   7991      2309  130404
# country_yard     46        14     964
# electronics    2091       477   57224
# furniture       991       218   27225
# kids            411        84   11924
# medicine          7         4     490
# sport          1266       260   27358
# stationery       10         2     262
# unknown         622       106   14815

# %%
# Dataviz de Quantidade de Eventos, por Categoria
main_category_events = df.groupby(['main_category', 'event_type']).size().unstack().fillna(0)

main_category_events.plot(kind='bar', stacked=True, figsize=(12,6))
plt.xlabel("Categoria Principal")
plt.ylabel("Número de Eventos")
plt.title("Eventos por Tipo de Evento em cada Categoria Principal")
plt.legend(title="Tipo de Evento")
plt.show()

# %%
# Análise do "Funil de Vendas": Cálculo de total de events, taxa de view_to_cart, taxa de cart_to_purchase
category_event_counts['total_events'] = category_event_counts.sum(axis=1)
category_event_counts['view_to_cart_rate'] = category_event_counts['cart'] / category_event_counts['view'] * 100
category_event_counts['cart_to_purchase_rate'] = category_event_counts['purchase'] / category_event_counts['cart'] * 100
category_event_counts
# Out:
# event_type     cart  purchase    view  total_events  view_to_cart_rate  \
# main_category
# accessories     201        36    9075          9312           2.214876
# apparel        2444       478   70444         73366           3.469423
# appliances     3491       786   89728         94005           3.890647
# auto            115        32    3969          4116           2.897455
# computers      1328       223   30070         31621           4.416362
# construction   7991      2309  130404        140704           6.127880
# country_yard     46        14     964          1024           4.771784
# electronics    2091       477   57224         59792           3.654061
# furniture       991       218   27225         28434           3.640037
# kids            411        84   11924         12419           3.446830
# medicine          7         4     490           501           1.428571
# sport          1266       260   27358         28884           4.627531
# ...

# %%
# Dataviz do Funil de Vendas
category_event_counts[['view','cart','purchase']].plot(
    kind='bar', stacked=True, figsize=(12,6)
)
plt.ylabel("Número de Eventos")
plt.xlabel("Categoria Principal")
plt.title("Eventos por Tipo em Cada Categoria")
plt.show()

# %%
# Dataviz da Evolução Diária de Eventos por Categoria Principal
df['date'] = pd.to_datetime(df['event_time']).dt.date
daily_category_events = df.groupby(['date','main_category']).size().unstack().fillna(0)

daily_category_events.plot(figsize=(12,6))
plt.ylabel("Número de Eventos")
plt.xlabel("Data")
plt.title("Evolução Diária de Eventos por Categoria")
plt.show()

# %% [markdown]
# ## Data Understanding e Data Preparation: brand

# %%
# Estatística de Quantidade de Marcas (brand)
list(df.brand.unique())
print(df['brand'].value_counts())
# Out:
# brand
# samsung    62217
# apple      39055
# xiaomi     34788
# huawei     12871
# lucente     7396
#            ...
# ferre          1
# toysmax        1
# amos           1
# samo           1
# flortek        1
# Name: count, Length: 3407, dtype: int64

# %%
# Dados nulos de brand
df['brand'].isnull().sum()
# Out:
# np.int64(71128)

# %%
# Tratamento de brand: Abordagem 1 - para os valores ausentes (NaN) de 'brand', inferir à partir de 'product_id'
prod_to_brand = (
    df.dropna(subset=['brand'])
      .drop_duplicates(subset=['product_id'])
      .set_index('product_id')['brand']
)

# Preencher brand usando o product_id
df['brand'] = df.apply(
    lambda row: prod_to_brand[row['product_id']] if pd.isna(row['brand']) and row['product_id'] in prod_to_brand else row['brand'],
    axis=1
)

# %%
# Tratamento de brand: Abordagem 2 - para os valores ausentes (NaN) de 'brand', inferir à partir de 'category_code' (para um data categoria, brand mais comum)
# Importante: com estas duas abordagens, não foi preciso preenchimento com 'unkown'
cat_to_brand = (
    df.dropna(subset=['brand'])
      .groupby('category_code')['brand']
      .agg(lambda x: x.value_counts().idxmax())
)

# Preencher brand com base na categoria
df['brand'] = df.apply(
    lambda row: cat_to_brand[row['category_code']] if pd.isna(row['brand']) and row['category_code'] in cat_to_brand else row['brand'],
    axis=1
)

# %%
# Estatística de Quantidade de Marcas (brand) - após tratamentos
df['brand'].value_counts(normalize=True) * 100 # Proporção relativa de cada item em relação ao todo
# Out:
# brand
# samsung     13.336133
# apple        7.980680
# xiaomi       7.158472
# lucente      3.156832
# huawei       2.574826
#               ...
# ecoline      0.000200
# klymit       0.000200
# hti          0.000200
# tomix        0.000200
# edu-play     0.000200
# Name: proportion, Length: 3407, dtype: float64

# %%
# Davaviz de participação de Brand
top5_brands = df['brand'].value_counts(normalize=True).head(5) * 100

# Criar gráfico de pizza
plt.figure(figsize=(8,8))
plt.pie(
    top5_brands,
    labels=top5_brands.index,
    autopct='%1.1f%%',      # mostra porcentagem com 1 casa decimal
    startangle=90,          # começa do topo
    counterclock=False      # sentido horário
)

plt.title("Top 5 Marcas por Participação (%)")
plt.show()

# %%
# Análise do Comportamento de brand em função do dos event_type
brand_counts = df.groupby(['brand','event_type']).size().unstack().fillna(0)
brand_counts['view_to_cart_rate'] = brand_counts['cart'] / brand_counts['view'] * 100
brand_counts['cart_to_purchase_rate'] = brand_counts['purchase'] / brand_counts['cart'] * 100
brand_counts
# Out:
# event_type  cart  purchase   view  view_to_cart_rate  cart_to_purchase_rate
# brand
# a-case       8.0       2.0  166.0           4.819277                   25.0
# a-derma      0.0       0.0   12.0           0.000000                    NaN
# a-elita      0.0       0.0    2.0           0.000000                    NaN
# a-mega       0.0       0.0    3.0           0.000000                    NaN
# aardwolf     1.0       1.0   13.0           7.692308                  100.0
# ...          ...       ...    ...                ...                    ...
# zte          1.0       0.0   62.0           1.612903                    0.0
# zubr         5.0       0.0  312.0           1.602564                    0.0
# zuru         0.0       0.0    1.0           0.000000                    NaN
# zwilling     0.0       0.0    3.0           0.000000                    NaN
# zyxel        0.0       0.0    7.0           0.000000                    NaN
#
# [3407 rows x 5 columns]

# %%
# Análise do comportamento de brand (top 5 mais solicitadas nas sessões)
total_events_per_brand = df['brand'].value_counts()
top5_brands = total_events_per_brand.head(5).index.tolist()

daily_brand_events = df.groupby(['date','brand']).size().unstack().fillna(0)
daily_top5 = daily_brand_events[top5_brands]

daily_top5.plot(figsize=(12,6))
plt.xlabel("Data")
plt.ylabel("Número de Eventos")
plt.title("Evolução Diária dos Eventos das Top 5 Marcas")
plt.show()

# %% [markdown]
# ## Data Understanding e Data Preparation: price

# %%
# Dataviz da Distribuição de price
df['price'].hist(bins=50, figsize=(10,5))
plt.xlabel("Preço")
plt.ylabel("Número de Produtos/Eventos")
plt.title("Distribuição de Preços")
plt.show()

# %%
# Análise de média de price por main_category
df.groupby('main_category')['price'].mean().sort_values(ascending=False)
# Out:
# main_category
# construction    400.934658
# electronics     357.512461
# appliances      291.672864
# auto            245.683625
# furniture       220.067480
# computers       203.982579
# apparel         187.870442
# kids            154.884720
# unknown         154.226831
# sport           154.215818
# accessories     120.641987
# stationery       73.608358
# country_yard     33.813223
# medicine         31.579361
# Name: price, dtype: float64

# %%
# Análise de média de price por brand
df.groupby('brand')['price'].mean().sort_values(ascending=False)
# Out:
# brand
# ego               2574.070
# cime              2558.370
# dreammachines     2543.825
# gravas            2496.850
# pinarello         2483.720
#                     ...
# lador                1.290
# beautyvisage         1.160
# purederm             1.060
# enlightenbrick       0.970
# skinlite             0.920
# Name: price, Length: 3407, dtype: float64

# %%
# Dataviz de Análise de Funil de Vendas - Conversão (purchase)
conversion = df.groupby(pd.cut(df['price'], bins=5))['event_type'].value_counts(normalize=True).unstack()

(conversion[['purchase']]*100).plot(kind='bar', figsize=(12,6))
plt.xlabel("Faixa de Preço")
plt.ylabel("Taxa de Compra (%)")
plt.title("Taxa de Compra por Faixa de Preço")
plt.show()
# Out:
# C:\Users\Walmir\AppData\Local\Temp\ipykernel_18604\2005759805.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   conversion = df.groupby(pd.cut(df['price'], bins=5))['event_type'].value_counts(normalize=True).unstack()

# %%
# Dataviz de Distribuição de Ticket Médio por Usuário
df[df['event_type']=='purchase'].groupby('user_id')['price'].mean().hist(bins=20, figsize=(10,5))
plt.xlabel("Ticket Médio por Usuário (Preço)")
plt.ylabel("Número de Usuários")
plt.title("Distribuição do Ticket Médio por Usuário")
plt.show()

# %%
# Análise de Amplitude de price, por main_category
plt.figure(figsize=(10,6))
sns.boxplot(x='main_category', y='price', data=df)
plt.xticks(rotation=45)
plt.title("Boxplot de Price por Categoria Principal")
plt.show()

# %%
# Verificação de dados Nulos (NaN)
df.isnull().sum()
# Out:
# event_time           0
# event_type           0
# product_id           0
# category_id          0
# category_code        0
# brand                0
# price                0
# user_id              0
# user_session         0
# date                 0
# hour                 0
# weekday              0
# main_category        0
# sub_category     15543
# dtype: int64

# %%
# Preenchimento de sub_category com Machine Learning - comentado, pois já foi rodado e armazenado em df_trat.csv - dados já tratados serão lidos em célula posterior
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split

# # Separar dados com sub_category preenchido
# df_train = df[df["sub_category"].notnull()]
# df_test = df[df["sub_category"].isnull()]

# X_train = pd.get_dummies(df_train[["category_id","brand","price"]])
# y_train = df_train["sub_category"]

# X_test = pd.get_dummies(df_test[["category_id","brand","price"]])
# X_test = X_test.reindex(columns=X_train.columns, fill_value=0)  # alinhar colunas

# # Treinar modelo
# model = RandomForestClassifier(n_estimators=100, random_state=42)
# model.fit(X_train, y_train)

# # Preencher os valores faltantes
# df.loc[df["sub_category"].isnull(), "sub_category"] = model.predict(X_test)

# %%
# Verificação de dados Nulos (NaN)
df.isnull().sum()
# Out:
# event_time           0
# event_type           0
# product_id           0
# category_id          0
# category_code        0
# brand                0
# price                0
# user_id              0
# user_session         0
# date                 0
# hour                 0
# weekday              0
# main_category        0
# sub_category     15543
# dtype: int64

# %%
# Salvamento dos dados tratados em CSV - comentado, pois já foi código já foi executado e dados armazenados para otimização do fluxo de testes
# df.to_csv(r"datasets\ecom_500k_trat.csv", index=False, encoding="utf-8")

# %%
df_trat = pd.read_csv(r"datasets\ecom_500k_trat.csv", )
df_trat['event_time'] = pd.to_datetime(df_trat['event_time'], utc=True)
df_trat.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category
# 0  construction        tools.light
# 1       apparel              shirt
# 2    appliances  personal.massager

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499995 entries, 0 to 499994
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     499995 non-null  datetime64[ns, UTC]
#  1   event_type     499995 non-null  object
#  2   product_id     499995 non-null  int64
#  3   category_id    499995 non-null  int64
#  4   category_code  499995 non-null  object
#  5   brand          499995 non-null  object
#  6   price          499995 non-null  float64
#  7   user_id        499995 non-null  int64
#  8   user_session   499995 non-null  object
#  9   date           499995 non-null  object
#  10  hour           499995 non-null  int32
#  11  weekday        499995 non-null  object
#  12  main_category  499995 non-null  object
#  13  sub_category   484452 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int32(1), int64(3), object(8)
# memory usage: 51.5+ MB

# %%
df_trat.isnull().sum()
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# date             0
# hour             0
# weekday          0
# main_category    0
# sub_category     0
# dtype: int64

# %% [markdown]
# ## Data Understanding e Data Preparation: user_id e user_session

# %%
# Análise de Quantidade de Eventos, por Sessão
list(df_trat.user_session.unique())
print(df_trat['user_session'].value_counts())
# Out:
# user_session
# 0ff295db-1fc8-46c2-8afc-03bb66c50b6c    275
# 9638a675-f9f4-4dd6-adea-faff0c62750f    273
# 799e3c45-0bc8-45bc-8f7b-4f2628cf47da    271
# 35bd1658-dbb4-4293-89bf-490015aaeab3    271
# 021f928e-5674-42f8-a847-674f2844fdc8    270
#                                        ...
# 7ab5d7c3-6cf9-48e0-832b-16270cb262bf      1
# c644b951-d797-4ffb-8d57-32a2a1563e9b      1
# 2572714a-6288-4d31-ae6b-b4d7cad88851      1
# 31aeb7ab-b5e2-4dab-9ae6-ac8024a00a25      1
# 061a4016-a6a1-4fde-b8f6-7f6674ddc84e      1
# Name: count, Length: 126462, dtype: int64

# %%
# Análise de Sessões inconsistentes: agrupar por user_session e contar quantos user_id distintos existem
inconsistencias = (
    df_trat.groupby("user_session")["user_id"]
      .nunique()
      .reset_index()
      .query("user_id > 1")   # pega apenas sessões com mais de 1 user_id
)
print(inconsistencias)
# Out:
#                                 user_session  user_id
# 14780   1e07f05c-63ec-4b9d-a36f-52bab071aa81        2
# 26800   35f4953b-4731-42e8-a795-13348a9d1816        2
# 27633   37ae3596-dde2-45f4-899c-fb1a4ae1151a        2
# 38926   4e91ec16-6772-4522-93fc-5133cf2520fa        2
# 39298   4f541c4d-461b-4080-bd2e-3b081819f953        2
# 40080   50eb6aa7-9176-481b-ab5d-a8f2fc3e7eee        2
# 57966   75474738-b1fb-4c0f-8e59-e214d807e121        2
# 62119   7d5ae5ff-e312-4469-8dd6-6ff3cdd4af4f        2
# 63051   7f4ac072-c4b7-4f93-bb64-f0f491bbaef9        2
# 66908   86f48744-d106-495a-8702-bde18931cc78        2
# 75899   991706de-754d-4736-b5db-05d2012411f1        2
# 118310  ef7274de-c8a5-478b-9758-25160329a684        2
# 124499  fc0779b6-f68d-4ee2-a2b1-cc0e7d5bd398        2

# %%
# Análise detalhada das sessões inconsistentes: event_type, product_id e category_id - Potenciais erros ou fraudes
registros_inconsistentes = df_trat[df_trat["user_session"].isin(inconsistencias["user_session"])]
print(registros_inconsistentes)
# Out:
#                       event_time event_type  product_id          category_id  \
# 39049  2019-12-01 02:27:07+00:00       view     1005159  2232732093077520756
# 39068  2019-12-01 02:27:09+00:00       view     1005159  2232732093077520756
# 39328  2019-12-01 02:27:39+00:00       view     1005159  2232732093077520756
# 39354  2019-12-01 02:27:42+00:00       view     1005159  2232732093077520756
# 136218 2020-01-01 03:19:03+00:00       view     5700675  2053013560866374351
# 136247 2020-01-01 03:19:07+00:00       view     5700675  2053013560866374351
# 154327 2020-01-01 04:00:01+00:00       view    20100148  2053013559473865347
# 154337 2020-01-01 04:00:02+00:00       view    20100148  2053013559473865347
# 158380 2020-01-01 04:07:59+00:00       view    20100148  2053013559473865347
# 158393 2020-01-01 04:08:00+00:00       view    20100148  2053013559473865347
# 179676 2020-01-01 04:40:15+00:00       view     1004939  2232732093077520756
# ...

# %%
# Análise de contagem de cada event_type por user_session
session_events = df_trat.groupby(['user_session','event_type']).size().unstack().fillna(0)
session_events
# Out:
# event_type                            cart  purchase  view
# user_session
# 0000b83c-9b26-4881-8bca-e20d460f4194   0.0       0.0   4.0
# 0000f7c4-8836-4507-82a1-8a10de3fb1b2   0.0       0.0   7.0
# 000100c3-a329-4a5b-ba91-a26d1e94dc34   1.0       1.0   9.0
# 00019736-fa18-4f53-abef-274471441c78   1.0       0.0   0.0
# 0002222c-3d01-4d6e-9120-87f09d362891   0.0       0.0   1.0
# ...                                    ...       ...   ...
# fffb0101-29e1-4d58-8c47-a3a8ea9b672f   0.0       0.0   1.0
# fffb5246-827b-4ada-9b94-384a029f5952   0.0       0.0   2.0
# fffc88df-6259-4b47-94c4-242f07c4d8e8   3.0       4.0   9.0
# fffdde82-64be-4f3b-a335-972fb176a31e   0.0       0.0   1.0
# ffff5194-3aed-4445-b308-17810d045950   0.0       0.0  12.0
#
# [126462 rows x 3 columns]

# %%
df_trat.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category
# 0  construction        tools.light
# 1       apparel              shirt
# 2    appliances  personal.massager

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499995 entries, 0 to 499994
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     499995 non-null  datetime64[ns, UTC]
#  1   event_type     499995 non-null  object
#  2   product_id     499995 non-null  int64
#  3   category_id    499995 non-null  int64
#  4   category_code  499995 non-null  object
#  5   brand          499995 non-null  object
#  6   price          499995 non-null  float64
#  7   user_id        499995 non-null  int64
#  8   user_session   499995 non-null  object
#  9   date           499995 non-null  object
#  10  hour           499995 non-null  int32
#  11  weekday        499995 non-null  object
#  12  main_category  499995 non-null  object
#  13  sub_category   484452 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int32(1), int64(3), object(8)
# memory usage: 51.5+ MB

# %%
df_trat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499995 entries, 0 to 499994
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     499995 non-null  datetime64[ns, UTC]
#  1   event_type     499995 non-null  object
#  2   product_id     499995 non-null  int64
#  3   category_id    499995 non-null  int64
#  4   category_code  499995 non-null  object
#  5   brand          499995 non-null  object
#  6   price          499995 non-null  float64
#  7   user_id        499995 non-null  int64
#  8   user_session   499995 non-null  object
#  9   date           499995 non-null  object
#  10  hour           499995 non-null  int64
#  11  weekday        499995 non-null  object
#  12  main_category  499995 non-null  object
#  13  sub_category   499995 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(4), object(8)
# memory usage: 53.4+ MB

# %%
# Análise de Tempo (em horas) desde a última sessão
df_sorted = df_trat.sort_values(['user_id','event_time'])
df_sorted['prev_session'] = df_sorted.groupby('user_id')['event_time'].shift(1)
df_sorted['time_since_last'] = (df_sorted['event_time'] - df_sorted['prev_session']).dt.total_seconds() / 3600
df_sorted
# Out:
#                       event_time event_type  product_id          category_id  \
# 312034 2020-03-01 01:17:01+00:00       view     5500105  2232732093941547400
# 313290 2020-03-01 01:22:32+00:00       view     5500207  2232732093941547400
# 313803 2020-03-01 01:24:32+00:00       view     5500109  2232732093941547400
# 314310 2020-03-01 01:26:41+00:00       view   100035299  2232732093941547400
# 314433 2020-03-01 01:27:10+00:00       view     5500221  2232732093941547400
# ...                          ...        ...         ...                  ...
# 499649 2020-04-01 04:08:06+00:00       view     1004657  2232732093077520756
# 499691 2020-04-01 04:08:09+00:00       view    21700004  2232732111012365062
# 499728 2020-04-01 04:08:12+00:00       view    21700004  2232732111012365062
# 499892 2020-04-01 04:08:23+00:00       view    19300086  2232732109418529498
# 499913 2020-04-01 04:08:24+00:00       view    13000085  2232732107489149609
#
# ...

# %%
# Taxa de Conversão por Sessão
purchased_sessions = df_trat[df_trat['event_type']=='purchase']['user_session'].nunique()
total_sessions = df_trat['user_session'].nunique()
conversion_rate = purchased_sessions / total_sessions * 100
print(f"Taxa de Conversão (purchase): {conversion_rate:.2f}%")
# Out:
# Taxa de Conversão (purchase): 3.37%

# %% [markdown]
# ## Mapa de Calor

# %%
# Mapa de Calor, por event_type e main_category
for etype in df_trat['event_type'].unique():
    heatmap_data = pd.crosstab(df_trat[df_trat['event_type']==etype]['main_category'], df_trat[df_trat['event_type']==etype]['event_type'])
    sns.heatmap(heatmap_data, annot=True, fmt="d")
    plt.title(f"Eventos {etype} por Categoria Principal")
    plt.show()

# %%
df_trat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499995 entries, 0 to 499994
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   event_time     499995 non-null  datetime64[ns, UTC]
#  1   event_type     499995 non-null  object
#  2   product_id     499995 non-null  int64
#  3   category_id    499995 non-null  int64
#  4   category_code  499995 non-null  object
#  5   brand          499995 non-null  object
#  6   price          499995 non-null  float64
#  7   user_id        499995 non-null  int64
#  8   user_session   499995 non-null  object
#  9   date           499995 non-null  object
#  10  hour           499995 non-null  int64
#  11  weekday        499995 non-null  object
#  12  main_category  499995 non-null  object
#  13  sub_category   499995 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(4), object(8)
# memory usage: 53.4+ MB

# %%
df_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 499995 entries, 312034 to 499913
# Data columns (total 16 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   event_time       499995 non-null  datetime64[ns, UTC]
#  1   event_type       499995 non-null  object
#  2   product_id       499995 non-null  int64
#  3   category_id      499995 non-null  int64
#  4   category_code    499995 non-null  object
#  5   brand            499995 non-null  object
#  6   price            499995 non-null  float64
#  7   user_id          499995 non-null  int64
#  8   user_session     499995 non-null  object
#  9   date             499995 non-null  object
#  10  hour             499995 non-null  int64
#  11  weekday          499995 non-null  object
#  12  main_category    499995 non-null  object
#  13  sub_category     499995 non-null  object
#  14  prev_session     401308 non-null  datetime64[ns, UTC]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Selecionar apenas colunas numéricas relevantes
numeric_cols = ['price', 'hour', 'time_since_last']  # você pode adicionar 'duration_minutes', contagens de eventos etc.
numeric_df = df_sorted[numeric_cols]

# Calcular correlação
corr = numeric_df.corr()

# Plotar heatmap
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", cbar=True)
plt.title("Mapa de calor de correlação")
plt.show()

# %% [markdown]
# # Dicionário de Dados (CSV tratado, com as novas Features)
#
# | Coluna         | Tipo de dado          | Máscara / Formato          | Descrição                                                                 | Exemplo                  |
# |----------------|----------------------|----------------------------|---------------------------------------------------------------------------|--------------------------|
# | **event_time** | datetime64[ns, UTC]  | YYYY-MM-DD HH:MM:SS        | Data e hora do evento (timestamp no fuso UTC).                            | 2025-09-28 12:34:56      |
# | **event_type** | string (object)      | texto                      | Tipo de evento: `view`, `cart`, `purchase`.           | view                     |
# | **product_id** | int64                | número inteiro             | Identificador único do produto.                                           | 123456                   |
# | **category_id**| int64                | número inteiro             | Identificador único da categoria.                                         | 98765                    |
# | **category_code** | string (object)   | texto com pontos           | Hierarquia da categoria no formato `categoria.subcategoria`.              | electronics.smartphone   |
# | **brand**      | string (object)      | texto                      | Marca do produto.                                                         | Samsung                  |
# | **price**      | float64              | ####.##                    | Preço do produto no momento do evento.                                   | 1599.90                  |
# | **user_id**    | int64                | número inteiro             | Identificador único do usuário (anônimo).                                | 456789                   |
# | **user_session** | string (object)    | UUID ou string de sessão   | Identificador da sessão de navegação.                                    | abc123-def456-ghi789     |
# | **date**       | string (object)      | YYYY-MM-DD                 | Data do evento extraída de `event_time`.                                 | 2025-09-28               |
# | **hour**       | int32                | número inteiro (0 a 23)    | Hora do evento (extraída de `event_time`).                               | 14                       |
# | **weekday**    | string (object)      | texto                      | Dia da semana do evento (ex.: Monday, Tuesday, …).                       | Sunday                   |
# | **main_category** | string (object)   | texto                      | Categoria principal do produto (primeiro nível da hierarquia).            | electronics              |
# | **sub_category**  | string (object)   | texto                      | Subcategoria do produto (nível mais específico da hierarquia).            | smartphone               |

# %% [markdown]
# ## Construção dos Modelos de Machine Learning

# %% [markdown]
# ### O dataset é bastante rico em oportunidades e aplicações - a seguir as Tarefas para Machine Learning sugeridas e possíveis aplicações:
# * Classificação - Target categórica: previsão se uma sessão vai resultar em compra; previsão de churn ou abandono; preços fora do padrão;
# * Regressão - Target numérica: previsão de preço de produto, com base na concorrência (marca); ticket médio por perfil de usuário; previsão de vendas diárias; tráfego por sessão;
# * Agrupamento: grupos de clientes mais rentáveis; grupos de produtos para planejamento de oferta;
#
# ### Para este estudo, foram escolhidas duas oportunidades, para Tarefas de Classificação e Agrupamento:
#
# * Modelo 1 - Aprendizado Não Supervisionado - Tarefa de Agrupamento - Grupos de Clientes mais Rentáveis
# * Modelo 2 - Aprendizado Supervisionado - Tarefa de Classificação - Possibilidade de Compra
# * Modelo 3 - Aprendizado Supervisionado - Tarefa de Classificação - Preços fora do Padrão

# %% [markdown]
# ## Modelo 1 - Agrupamento - Grupos de Clientes mais Rentáveis
#
# ### Problema a ser endereçado:
# * Evidentemente, um importante enfoque de um Ecommerce é otimizar suas vendas; para tal,  são atividades de interesse de gerentes de vendas e marketing analisar gastos por cluster (clientes mais rentáveis), distribuição de clientes por cluster (quantidades), relação de gastos vs. frequência e distribuição de recência por cluster (quais os clientes mais assíduos) - assim, pensamos que possam ser melhor dirigidas as campanhas de marketing e vendas.
#
# ### Objetivo:
# * Construção de um Modelo de ML para Segmentação de Clientes mais Rentáveis
#
# ### Abordagem de negócio:
# * Para a preparação dos dados, pensamos na abordagem RFM: Recency (tempo desde última compra), Frequency (número de compras) e Monetary (total gasto)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from datetime import datetime

df_trat.isnull().sum()
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# date             0
# hour             0
# weekday          0
# main_category    0
# sub_category     0
# dtype: int64

# %%
# Filtrar apenas as transações que resultaram em compras
purchases = df_trat[df_trat["event_type"] == "purchase"]

# %%
# Agregar por cliente (user_id) o total gasto (total_spent), frequência (frequency) e data hora a última compra (last_purchase) 
agg = purchases.groupby("user_id").agg(
    total_spent=("price", "sum"),
    frequency=("product_id", "count"),
    last_purchase=("event_time", "max")
).reset_index()

agg
# Out:
#         user_id  total_spent  frequency             last_purchase
# 0     493948852       386.08          1 2020-04-01 03:37:05+00:00
# 1     512364027        11.84          1 2020-03-01 03:10:07+00:00
# 2     512365013       493.96          1 2020-02-01 00:50:10+00:00
# 3     512383188        19.82          1 2019-12-01 01:10:04+00:00
# 4     512383276       125.85          1 2020-02-01 02:29:33+00:00
# ...         ...          ...        ...                       ...
# 3892  635203889        76.91          1 2020-04-01 03:53:23+00:00
# 3893  635204000       222.87          1 2020-04-01 03:59:06+00:00
# 3894  635205266       148.49          1 2020-04-01 04:02:19+00:00
# 3895  635205867        43.76          1 2020-04-01 04:01:36+00:00
# 3896  635206469       192.28          1 2020-04-01 04:08:08+00:00
#
# [3897 rows x 4 columns]

# %%
# Recency (em dias)
agg["last_purchase"] = pd.to_datetime(agg["last_purchase"])
max_date = pd.to_datetime(df_trat["event_time"]).max()
agg["recency_days"] = (max_date - agg["last_purchase"]).dt.days

agg
# Out:
#         user_id  total_spent  frequency             last_purchase  \
# 0     493948852       386.08          1 2020-04-01 03:37:05+00:00
# 1     512364027        11.84          1 2020-03-01 03:10:07+00:00
# 2     512365013       493.96          1 2020-02-01 00:50:10+00:00
# 3     512383188        19.82          1 2019-12-01 01:10:04+00:00
# 4     512383276       125.85          1 2020-02-01 02:29:33+00:00
# ...         ...          ...        ...                       ...
# 3892  635203889        76.91          1 2020-04-01 03:53:23+00:00
# 3893  635204000       222.87          1 2020-04-01 03:59:06+00:00
# 3894  635205266       148.49          1 2020-04-01 04:02:19+00:00
# 3895  635205867        43.76          1 2020-04-01 04:01:36+00:00
# 3896  635206469       192.28          1 2020-04-01 04:08:08+00:00
#
#       recency_days
# 0                0
# 1               31
# 2               60
# 3              122
# 4               60
# ...            ...
# 3892             0
# ...

# %%
# Escalonamento de features - importante para que agrupamento total_spent, frequency e recency_days fiquem na mesma escala
# Valores abaixo da média viram negativos; Valores acima da média viram positivos; Valores iguais à média viram 0

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X = agg[["total_spent", "frequency", "recency_days"]]

X_scaled = scaler.fit_transform(X)

# Exportação de dados para testes no Streamlit - Modelo K-Means
agg.to_csv(r"datasets\cluster_test.csv", index=False, encoding="utf-8")

# %%
# Técnica de Elbow e Silhouete Score
from sklearn.metrics import silhouette_score

k_values = range(2, 11)  # de 2 a 10 clusters
sil_scores = []
inertia_values = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(X_scaled)
    
    sil = silhouette_score(X_scaled, labels)
    sil_scores.append(sil)
    
    inertia_values.append(kmeans.inertia_)

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(k_values, sil_scores, marker='o')
plt.title("Silhouette Score vs. Número de Clusters")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Silhouette Score")
plt.grid(True)

plt.subplot(1,2,2)
plt.plot(k_values, inertia_values, marker='o', color='orange')
plt.title("Inertia (WCSS) vs. Número de Clusters")
plt.xlabel("Número de clusters (k)")
plt.ylabel("Inertia (WCSS)")
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Clusterização
kmeans = KMeans(n_clusters=8, random_state=42)
agg['cluster'] = kmeans.fit_predict(X_scaled)

# Identificar cluster mais lucrativo
cluster_summary = agg.groupby("cluster").agg(
    avg_spent=("total_spent","mean"),
    total_spent=("total_spent","sum"),
    customers=("user_id","count")
)
print(cluster_summary.sort_values("total_spent", ascending=True))
# Out:
#            avg_spent  total_spent  customers
# cluster
# 3        5313.135000     53131.35         10
# 5         992.704444     80409.06         81
# 7         363.635083    130908.63        360
# 1         187.090219    171000.46        914
# 2        2107.080217    193851.38         92
# 4         271.633492    217035.16        799
# 6         169.036620    217550.13       1287
# 0         988.422853    349901.69        354

# %% [markdown]
# # Modelo 1 - Análise do Desempenho do Modelo
#
# ## Inertia ou WCSS (Within Cluster Sum of Squared):
# > ###  Inertia mede o quão próximos os pontos de dados estão do centróide do cluster, portanto, quando menor, melhor; no entanto, quanto mais clusters, mais centróides estão disponíveis, então cada ponto tende a ficar mais perto de algum centróide.
# > ###  O "ponto ideal" é o ponto do cotovelo (Método de Elbow) - no projeto, percebe-se algo em torno de do tamanho 4.
#
# ## Silhouete Score:
# > ###  Silhouette mede se os clusters são bem separados e coesos.
# > ###  Para poucos clusters, pode ser baixo, portanto, clusters grandes e sobrepostos; para clusters demais, pode cair também, portanto, alguns clusters ficam muito pequenos ou sobrepostos, diminuindo a média do Silhouette.
# > ###  Valores entre 0.7-1.0 mostram cluster muito bem definido; 0.5-0.7 mostram boa separação; 0.25-0.5 mostram clusters sobrepostos.
#
# ## Análise final:
# > ###  Apesar da Inertia nos indicar a quantidade de clusters no intervalo de 3 a 5, Silhouette Score nos apresenta quantidade de 8 clusters com desempenho bem melhor (entre 0.5-0.7), com grande distância de score entre 7 e 8 clusters.
# > ### Analisando os clusters formados, percebe-se que:
# - Cluster mais lucrativo: 0 - maior média de gastos e maior total de gastos (354 customers)
# - Clusteres de maior representatividade: 4 e 6 tem boa total de gastos, bem parecido, e juntos a maior quantidade de clientes (799+1287=2086 customers)
# - Cluster de menor representatividade: 3 pois tem o total de gasto mais baixo e baixa quantidade de clientes (10 customers)

# %%
agg.head(10)
# Out:
#      user_id  total_spent  frequency             last_purchase  recency_days  \
# 0  493948852       386.08          1 2020-04-01 03:37:05+00:00             0
# 1  512364027        11.84          1 2020-03-01 03:10:07+00:00            31
# 2  512365013       493.96          1 2020-02-01 00:50:10+00:00            60
# 3  512383188        19.82          1 2019-12-01 01:10:04+00:00           122
# 4  512383276       125.85          1 2020-02-01 02:29:33+00:00            60
# 5  512384254      1124.61          1 2020-02-01 01:13:35+00:00            60
# 6  512384271       134.17          1 2020-02-01 02:57:08+00:00            60
# 7  512385385       450.44          1 2020-03-01 00:25:08+00:00            31
# 8  512389330        47.36          1 2019-12-01 03:38:57+00:00           122
# 9  512391887       164.46          1 2020-04-01 04:07:35+00:00             0
#
#    cluster
# 0        1
# 1        6
# 2        6
# 3        4
# 4        6
# 5        0
# 6        6
# 7        6
# ...

# %%
agg.shape
# Out:
# (3897, 6)

# %%
df.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category
# 0  construction        tools.light
# 1       apparel              shirt
# 2    appliances  personal.massager

# %%
# Alguns user_id não estão atribuidos à nenhum cluster por não terem registro de venda
# Portanto, muitos registros do df não terão um grupo associado!
df = df.merge(agg[["user_id", "cluster"]], on="user_id", how="left")

# %%
df.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category  cluster
# 0  construction        tools.light      NaN
# 1       apparel              shirt      NaN
# ...

# %%
# Somente os registros que tem rótulo de cluster atribuídos
df_filtered = df[df["cluster"].notnull()]
df_filtered.head(3)
# Out:
#                   event_time event_type  product_id          category_id  \
# 3  2019-12-01 00:00:02+00:00   purchase    26400248  2053013553056579841
# 14 2019-12-01 00:00:06+00:00       view     3701309  2053013565983425517
# 27 2019-12-01 00:00:10+00:00       view    37900170  2152167773222993940
#
#                     category_code    brand   price    user_id  \
# 3   computers.peripherals.printer  lucente  132.31  535135317
# 14  appliances.environment.vacuum  polaris   89.32  543733099
# 27    auto.accessories.compressor     vega   34.05  539618099
#
#                             user_session        date  hour weekday  \
# 3   61792a26-672f-4e61-9832-7b63bb1714db  2019-12-01     0  Sunday
# 14  a65116f4-ac53-4a41-ad68-6606788e674c  2019-12-01     0  Sunday
# 27  2d82cd98-f9df-4498-b81d-0a678ea2eae2  2019-12-01     0  Sunday
#
#    main_category            sub_category  cluster
# 3      computers     peripherals.printer      4.0
# ...

# %%
# Total de linhas e colunas com cluster atribuido
df_filtered.shape
# Out:
# (38705, 15)

# %%
# Exportação do Modelo 1 - Agrupamento - Grupos de Clientes mais Rentáveis
import joblib
joblib.dump(kmeans, r"datasets\modelo_kmeans.pkl")
# Out:
# ['datasets\\modelo_kmeans.pkl']

# %% [markdown]
# ## Modelo 2 - Classificação - Possibilidade de Compra
#
# ### Problema a ser endereçado:
# * Outro importante aspecto na gestão de vendas de um Ecommerce é acompanhar as sessões e analisar as possibilidades de conversão destas sessões, ainda no estágio de "view" e "cart", em vendas. Uma vez classificadas tais sessões, aplicação de Ecommerce pode tomar ações para fomentar que o cliente conversa a sessão em "purchase".
# * Portanto, são atividades de interesse de gerentes de vendas a análise de registros de sessões para classificá-las como possibilidade de conversão para venda; também se faz interessante a análise por marcas e categorias. Por fim, também se considera importante saber quais os dias da semana são os mais rentáveis.
#
# ### Objetivo:
# * Construção de um Modelo de ML para Classificação de Sessões em termos de Possibilidade de Compra
#
# ### Abordagem de negócio:
# * Para a preparação dos dados, pensamos na abordagem de agrupar, para cada sessão, quantas vezes adicionou ao carrinho (quanto mais, mais demonstra interesse na compra) e quantos produtos inseriu no carrinho (quanto mais, mais demonstra interesse na compra e compra é mais qualificada).
# * Classes: purchase_target=1 (comprou na sessão); purchase_target=0 (não comprou na sessão).

# %%
# Primeiro, criação de uma coluna indicando quando event_type='purchase'
df_trat['purchase_target'] = df_trat['event_type'].apply(lambda x: 1 if x=="purchase" else 0)
df_trat.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category  purchase_target
# 0  construction        tools.light                0
# 1       apparel              shirt                0
# ...

# %%
# Análise de Quantidade de Compras (purchase=1)
counts = df_trat['purchase_target'].value_counts()
percent = df_trat['purchase_target'].value_counts(normalize=True) * 100

df_summary = pd.DataFrame({'Quantidade': counts, 'Porcentagem (%)': percent})
print(df_summary)
# Out:
#                  Quantidade  Porcentagem (%)
# purchase_target
# 0                    494966         98.99419
# 1                      5029          1.00581

# %%
# Gráfico comparativo - Quantidade de Compras (purchase=1)
plt.figure(figsize=(6,4))
sns.countplot(data=df_trat, x='purchase_target', palette=['skyblue', 'salmon'])
plt.xticks([0,1], ['Não Compra', 'Compra'])
plt.ylabel('Quantidade de Registros')
plt.title('Comparação: Compras vs Não Compras')
plt.show()
# Out:
# C:\Users\Walmir\AppData\Local\Temp\ipykernel_18604\3399533298.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_trat, x='purchase_target', palette=['skyblue', 'salmon'])

# %%
# Balanceando a base

from sklearn.utils import resample

# Separar classes
df_majority = df_trat[df_trat['purchase_target'] == 0]
df_minority = df_trat[df_trat['purchase_target'] == 1]

# Undersample da classe majoritária
df_majority_downsampled = resample(
    df_majority,
    replace=False,
    n_samples=len(df_minority),
    random_state=42
)

# Combinar e embaralhar
df_balanced = pd.concat([df_majority_downsampled, df_minority])
df_balanced = df_balanced.sample(frac=1, random_state=42)

# %%
# Agrupar por usuário/sessão para contagem de quantas vezes o cliente comprou (event_type=cart) e quantidade de produtos (product_id no carrinho de compras)
session_features = df_balanced.groupby("user_session").agg({
    "event_type": lambda x: (x=="cart").sum(),  # contador de quantas vezes adicionou ao carrinho (quanto mais, mais demonstra interesse na compra)
    "product_id": "count"                       # contador de quantos produtos inseriu no carrinho (quanto mais, mais demonstra interesse na compra e compra é mais qualificada)
}).rename(columns={"event_type":"add_to_cart_count","product_id":"views_count"})

# %%
print(session_features)
# Out:
#                                       add_to_cart_count  views_count
# user_session
# 000100c3-a329-4a5b-ba91-a26d1e94dc34                  0            1
# 0005d669-b4bc-429d-8833-8034b8690b1e                  0            1
# 00251346-e185-4648-9cf7-c8fead6fe7d4                  0            1
# 003762ff-cce1-448b-86d9-999a39a1d7fe                  0            1
# 003c31bc-7b28-4890-bf01-5ee3ff775777                  0            1
# ...                                                 ...          ...
# ffe6a04f-961b-40fa-bdd5-37685253c0a2                  0            1
# ffe7f857-d913-4d92-81d2-d0e5df801c9b                  0            1
# ffec251d-41d8-4957-9a92-53a70e66a3bd                  0            1
# ffece37f-574e-4dc0-a5e2-804a03e14ce2                  0            1
# fffc88df-6259-4b47-94c4-242f07c4d8e8                  0            4
#
# [8715 rows x 2 columns]

# %%
# Merge dos dados processados com o dataframe original
session_features = session_features.reset_index()
df_balanced = df_balanced.merge(session_features, on="user_session", how="left")

df_balanced.head(2)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2020-03-01 03:41:23+00:00   purchase     1004838  2232732093077520756
# 1 2020-02-01 03:14:25+00:00       view    26900065  2232732098303623659
#
#                category_code          brand   price    user_id  \
# 0   construction.tools.light           oppo  166.03  559166874
# 1  apparel.shoes.espadrilles  bodysculpture  103.45  599290974
#
#                            user_session        date  hour   weekday  \
# 0  02582757-ae20-498d-970c-da0536821fab  2020-03-01     3    Sunday
# 1  79f5a8b8-c574-4656-9c41-64139121baeb  2020-02-01     3  Saturday
#
#   main_category       sub_category  purchase_target  add_to_cart_count  \
# 0  construction        tools.light                1                  0
# 1       apparel  shoes.espadrilles                0                  0
#
#    views_count
# 0            1
# 1            2

# %%
df_balanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10058 entries, 0 to 10057
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_time         10058 non-null  datetime64[ns, UTC]
#  1   event_type         10058 non-null  object
#  2   product_id         10058 non-null  int64
#  3   category_id        10058 non-null  int64
#  4   category_code      10058 non-null  object
#  5   brand              10058 non-null  object
#  6   price              10058 non-null  float64
#  7   user_id            10058 non-null  int64
#  8   user_session       10058 non-null  object
#  9   date               10058 non-null  object
#  10  hour               10058 non-null  int64
#  11  weekday            10058 non-null  object
#  12  main_category      10058 non-null  object
#  13  sub_category       10058 non-null  object
#  14  purchase_target    10058 non-null  int64
# ...

# %%
# Gráfico comparativo - Quantidade de Compras (purchase=1)
plt.figure(figsize=(6,4))
sns.countplot(data=df_balanced, x='purchase_target', palette=['skyblue', 'salmon'])
plt.xticks([0,1], ['Não Compra', 'Compra'])
plt.ylabel('Quantidade de Registros')
plt.title('Comparação: Compras vs Não Compras (Balanceada)')
plt.show()
# Out:
# C:\Users\Walmir\AppData\Local\Temp\ipykernel_18604\3747666245.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_balanced, x='purchase_target', palette=['skyblue', 'salmon'])

# %%
# Codificação das variáveis categóricas para o Modelo
from sklearn.preprocessing import LabelEncoder

# Criando LabelEncoders para cada coluna
le_main_category = LabelEncoder()
le_brand = LabelEncoder()
le_sub_category = LabelEncoder()
le_weekday = LabelEncoder()

# Aplicando LabelEncoder em cada coluna do df_trat
df_balanced['main_category_encoded'] = le_main_category.fit_transform(df_balanced['main_category'])
df_balanced['sub_category_encoded'] = le_sub_category.fit_transform(df_balanced['sub_category'])
df_balanced['brand_encoded'] = le_brand.fit_transform(df_balanced['brand'])
df_balanced['weekday_encoded'] = le_weekday.fit_transform(df_balanced['weekday'])

# Mostrar mapeamento das categorias
print("\nCategorias mapeadas - main_category:", list(le_main_category.classes_))
print("Categorias mapeadas - brand:", list(le_brand.classes_))
print("Categorias mapeadas - sub_category:", list(le_sub_category.classes_))
print("Categorias mapeadas - weekday:", list(le_weekday.classes_))
# Out:
# Categorias mapeadas - main_category: ['accessories', 'apparel', 'appliances', 'auto', 'computers', 'construction', 'country_yard', 'electronics', 'furniture', 'kids', 'medicine', 'sport', 'stationery', 'unknown']
# ...

# %%
df_balanced.head(2)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2020-03-01 03:41:23+00:00   purchase     1004838  2232732093077520756
# 1 2020-02-01 03:14:25+00:00       view    26900065  2232732098303623659
#
#                category_code          brand   price    user_id  \
# 0   construction.tools.light           oppo  166.03  559166874
# 1  apparel.shoes.espadrilles  bodysculpture  103.45  599290974
#
#                            user_session        date  ...   weekday  \
# 0  02582757-ae20-498d-970c-da0536821fab  2020-03-01  ...    Sunday
# 1  79f5a8b8-c574-4656-9c41-64139121baeb  2020-02-01  ...  Saturday
#
#   main_category       sub_category purchase_target  add_to_cart_count  \
# 0  construction        tools.light               1                  0
# 1       apparel  shoes.espadrilles               0                  0
#
#    views_count  main_category_encoded  sub_category_encoded  brand_encoded  \
# ...

# %%
# Seleção de features de interesse para classificação
# Selecionar features
X = df_balanced[["price","brand_encoded","main_category_encoded","sub_category_encoded","hour","weekday_encoded","add_to_cart_count","views_count"]]
y = df_balanced["purchase_target"]
X.head()
# Out:
#     price  brand_encoded  main_category_encoded  sub_category_encoded  hour  \
# 0  166.03            616                      5                   109     3
# 1  103.45            129                      1                    90     3
# 2  306.74             52                     11                    19     3
# 3  870.42            539                      1                    96     3
# 4  167.55            773                      1                    88     0
#
#    weekday_encoded  add_to_cart_count  views_count
# 0                1                  0            1
# 1                0                  0            2
# 2                1                  0            1
# 3                2                  0            1
# 4                1                  0            1

# %%
# Como o percentual de dados da classe purchase_target=1 é baixísimo (~1%), vamos adotar a  abordagem:

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Supondo que X, y já estejam preparados
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

rf = RandomForestClassifier(n_estimators=200, max_depth=10, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.69      0.68      1532
#            1       0.67      0.65      0.66      1486
#
#     accuracy                           0.67      3018
#    macro avg       0.67      0.67      0.67      3018
# weighted avg       0.67      0.67      0.67      3018

# %%
# Avaliação de Desempenho do Modelo em Classificação Binária - ROC e AUC (Area Under the Curve)
# No gráfico, percebe-se AUC=0.73 - bom resultado separação entre classes pois AUC=1.0 é perfeito!

from sklearn.metrics import roc_curve, auc, RocCurveDisplay

# Probabilidade de compra (classe 1)
y_probs = rf.predict_proba(X_test)[:, 1]

# Curva ROC e AUC

fpr, tpr, thresholds = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Visualização
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("Falso Positivo (FPR)")
plt.ylabel("Verdadeiro Positivo (TPR)")
plt.title("Curva ROC")
plt.legend()
plt.show()

# %%
# Avaliação de Desempenho do Modelo em Classificação Binária - PRC (Precision Recall Curve)

from sklearn.metrics import precision_recall_curve, average_precision_score, PrecisionRecallDisplay
import matplotlib.pyplot as plt


# y_prob = probabilidades preditas pelo modelo para a classe positiva
y_prob = rf.predict_proba(X_test)[:, 1]

# y_true = rótulos reais (0 ou 1)
y_true = y_test

# Calcula precision, recall e thresholds
precision, recall, thresholds = precision_recall_curve(y_true, y_prob)

# Calcula Average Precision
ap = average_precision_score(y_true, y_prob)
print(f"Average Precision (AP): {ap:.2f}")

# Visualização
disp = PrecisionRecallDisplay(precision=precision, recall=recall)
disp.plot()
plt.title("Curva Precision-Recall")
plt.show()
# Out:
# Average Precision (AP): 0.72

# %%
# Preparação de Dados para testes
df_trat_test = df_trat.copy()

# Session features para df_trat_test
# Agrupar por usuário/sessão para contagem de quantas vezes o cliente comprou (event_type=cart) e quantidade de produtos (product_id no carrinho de compras)
session_features2 = df_trat_test.groupby("user_session").agg({
    "event_type": lambda x: (x=="cart").sum(),  # contador de quantas vezes adicionou ao carrinho (quanto mais, mais demonstra interesse na compra)
    "product_id": "count"                       # contador de quantos produtos inseriu no carrinho (quanto mais, mais demonstra interesse na compra e compra é mais qualificada)
}).rename(columns={"event_type":"add_to_cart_count","product_id":"views_count"})

# Merge dos dados processados com o dataframe original (mesmo session_features)
df_trat_test = df_trat_test.merge(session_features2, on="user_session", how="left")

# Codificação com o mesmo Label Encoder
df_trat_test['main_category_encoded'] = le_main_category.fit_transform(df_trat_test['main_category'])
df_trat_test['sub_category_encoded'] = le_sub_category.fit_transform(df_trat_test['sub_category'])
df_trat_test['brand_encoded'] = le_brand.fit_transform(df_trat_test['brand'])
df_trat_test['weekday_encoded'] = le_weekday.fit_transform(df_trat_test['weekday'])

df_trat_test.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  hour weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01     0  Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01     0  Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01     0  Sunday
#
#   main_category       sub_category  add_to_cart_count  views_count  \
# 0  construction        tools.light                  0            1
# ...

# %%
# Exportação de dados para testes no Streamlit - Modelo RandomForest (dados originais totais, sem o balanceamento)
colunasdesejadas = ["price", "brand_encoded", "main_category_encoded", "sub_category_encoded", \
    "hour", "weekday_encoded", "add_to_cart_count", "views_count"]
df_trat_testf = df_trat_test[colunasdesejadas]
df_trat_testf.to_csv(r"datasets\randomforest_test2.csv", index=False, encoding="utf-8")
df_trat_testf.head(3)
# Out:
#      price  brand_encoded  main_category_encoded  sub_category_encoded  hour  \
# 0  1302.48            167                      5                   119     0
# 1   102.96           1104                      1                    96     0
# 2   313.52            457                      2                    92     0
#
#    weekday_encoded  add_to_cart_count  views_count
# 0                1                  0            1
# 1                1                  0           11
# 2                1                  1            8

# %%
df_trat_testf.shape
# Out:
# (499995, 8)

# %%
# Exportação do Modelo 2 - Classificação - Possibilidade de Compra
import joblib
joblib.dump(rf, r"datasets\modelo_randomforest.pkl")
joblib.dump(le_main_category, r"datasets\le_main_category.pkl")
joblib.dump(le_sub_category, r"datasets\le_sub_category.pkl")
joblib.dump(le_brand, r"datasets\le_brand.pkl")
joblib.dump(le_weekday, r"datasets\le_weekday.pkl")
# Out:
# ['datasets\\le_weekday.pkl']

# %% [markdown]
# # Modelo 2 - Análise do Desempenho do Modelo
#
# ## Métrica escolhida:
# > ### Dado que pretende-se prever se, em uma dada sessão, o cliente vai fazer a compra (para insistir com ele, para voltar ao carrinho, por exemplo)
# > ### Dado que a classe purchase_target=1 é infinitamente menos representativa (apenas ~1% das observações)
# > ### Foi utilizada técnica de reamostragem, para conseguir um undersampling da classe majoritária (reduzir amostras majoritárias e repetir amostras minoritárias); n_samples=len(df_minority) reduz o número de amostras da classe majoritária para ter o mesmo número de exemplos da classe minoritária
# > ### Ao analisar a Curva ROC, obtivemos AUC=0.73, o que significa que o modelo agora consegue classificar melhor as classes positivias (purchase_target=1), do que para um negativo aleatório
# > ### Ao analisar a curva PRC, percebe-se que quando Recall=1, Precision fica próximo de 0.5 - Neste caso, a métrica Recall (Revocação ou Sensibilidade) nos pareceu ser a mais interessante pois desejamos encontrar o maior número de compras possível - para nosso case, não queremos perder as classificações positivas e conversão de Compras

# %% [markdown]
# ## Modelo 3 - Classificação - Preços fora do Padrão
#
# ### Problema a ser endereçado:
# * Um olhar que também chama a atenção a gestão de vendas de um Ecommerce é acompanhar o posicionamento de mercado dos produtos vendidos por meio da verificação de preços em relação às vendas, ou seja, preços fora do padrão.
# * Portanto, são atividades de interesse de gerentes de vendas verificar produtos fora de padrão por categoria, assim apoiando a gestão de portfólio de produtos; análise de variações de preços fora do padrão por meio de estatísticas por categoria; análise de produtos com preços fora do padrão por marca; por fim, distribuição geral de produtos com preços adequados vs. produtos com preços fora do padrão.
#
# ### Objetivo:
# * Construção de um Modelo de ML para Classificação de Produtos com Preços fora do Padrão
#
# ### Abordagem de negócio:
# * Para a preparação dos dados, pensamos na abordagem estatística de separar os dados por quartis, para então separar os outliers. Como os dados originalmente não estão rotulados, pensamos em rotular com base nesta abordagem estatística para depois treinar o modelo, com base nesta rotulagem estatística.
# * Classes: outlier=1 (preço fora do padrão); outlier=0 (preço normal)

# %%
df_trat.head(3)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-12-01 00:00:00+00:00       view     1005105  2232732093077520756
# 1 2019-12-01 00:00:00+00:00       view    22700068  2232732091643068746
# 2 2019-12-01 00:00:01+00:00       view     2402273  2232732100769874463
#
#                   category_code  brand    price    user_id  \
# 0      construction.tools.light  apple  1302.48  556695836
# 1                 apparel.shirt  force   102.96  577702456
# 2  appliances.personal.massager  bosch   313.52  539453785
#
#                            user_session        date  ...  weekday  \
# 0  ca5eefc5-11f9-450c-91ed-380285a0bc80  2019-12-01  ...   Sunday
# 1  de33debe-c7bf-44e8-8a12-3bf8421f842a  2019-12-01  ...   Sunday
# 2  5ee185a7-0689-4a33-923d-ba0130929a76  2019-12-01  ...   Sunday
#
#   main_category       sub_category purchase_target  add_to_cart_count  \
# 0  construction        tools.light               0                  0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
# Separação de dados por Quartis (outliers)
# Obter os dados dentro da regra empírica de Tukey: 1.5 expande o intervalo central em 1.5 o IQR para capturar valores extremos

# Calcular Q1, Q3 e IQR
Q1 = df_trat.groupby("category_id")["price"].transform(lambda x: x.quantile(0.25))
Q3 = df_trat.groupby("category_id")["price"].transform(lambda x: x.quantile(0.75))
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %%
# Rotulagem dos Dados que são outliers
df_trat["outlier"] = (~df_trat["price"].between(limite_inferior, limite_superior)).astype(int)

# %%
# Criar razão do preço pelo preço médio por categoria
df_trat["price_ratio_cat"] = df_trat.groupby("category_id")["price"].transform(lambda x: x / x.mean())

# %%
df_trat = df_trat[df_trat["price_ratio_cat"].notnull()]

# %%
X = df_trat[['price', 'price_ratio_cat']]
y = df_trat['outlier']

# Split e treino
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X.shape)
print(y.shape)
# Out:
# (499992, 2)
# (499992,)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

# Avaliação Conj. Testes (X_test)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    139988
#            1       0.82      0.68      0.74     10010
#
#     accuracy                           0.97    149998
#    macro avg       0.90      0.83      0.86    149998
# weighted avg       0.97      0.97      0.97    149998

# %% [markdown]
# ### Balanceando a base

# %%
from sklearn.utils import resample

# Separar classes
df_majority = df_trat[df_trat['outlier'] == 0]
df_minority = df_trat[df_trat['outlier'] == 1]

# Undersample da classe majoritária
df_majority_downsampled = resample(
    df_majority,
    replace=False,
    n_samples=len(df_minority),
    random_state=42
)

# Combinar e embaralhar
df_balanced = pd.concat([df_majority_downsampled, df_minority])
df_balanced = df_balanced.sample(frac=1, random_state=42)

# Separar X e y
X = df_balanced[['price', 'price_ratio_cat']]
y = df_balanced['outlier']

# Split normal
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (46558, 2)
# (46558,)

# %%
model = LogisticRegression(class_weight='balanced')
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
# Avaliação Conj. Testes (X_test)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91      9920
#            1       0.92      0.90      0.91     10034
#
#     accuracy                           0.91     19954
#    macro avg       0.91      0.91      0.91     19954
# weighted avg       0.91      0.91      0.91     19954

# %% [markdown]
# # Modelo 3 - Análise do Desempenho do Modelo
#
# ## Recorte de Percentis:
#
# > ### Para este modelo, foi feito recorte estatístico de intervalos (percentis) e, dentro deste recorte, rotulagem do que estiver fora do padrão
# > ### Com base nesta rotulagem, foram treinados os dados
#
# ## Métrica escolhida:
# > ### Dado que pretende-se classificar preços fora do padrão (outlier=1) - um FALSO NEGATIVO (ou seja, Preço classificado que não está fora do padrão, mas na realidade está),
# > ### tem um custo importante para o negócio pois o produto pode ficar "encalhado" nas vendas por mau posicionamento no mercado.
# > ### Um preço fora do padrão tem um impacto importante nas vendas (quer seja pela não conversão, quer seja pelo posicionamnto de marca)
# > ### Neste caso, a métrica Recall (Revocação ou Sensibilidade) parece ser a mais interessante - obtivemos uma performance bem interessante para Recall, principalmente para outlier=0 (ou seja, exatamente o que não gostaríamos que ocorresse).

# %%
# Avaliação Conj. Treinamento (X_train)
y_pred2 = model.predict(X_train)
print(classification_report(y_train, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98    326748
#            1       0.81      0.67      0.74     23246
#
#     accuracy                           0.97    349994
#    macro avg       0.90      0.83      0.86    349994
# weighted avg       0.97      0.97      0.97    349994

# %%
import numpy as np
y_combined = list(zip(y_pred, y_pred2))
print(y_pred.shape)
print(y_pred2.shape)
print(X.shape)
y_combined = np.concatenate([y_pred, y_pred2])
print(y_combined.shape)
# Out:
# (149998,)
# (349994,)
# (499992, 2)
# (499992,)

# %%
X['oulier previsto'] = y_combined
X
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_7768\1648757875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['oulier previsto'] = y_combined
#           price  price_ratio_cat  oulier previsto
# 0       1302.48         2.986884                0
# 1        102.96         0.948712                0
# 2        313.52         2.624598                0
# 3        132.31         0.472438                0
# 4        101.68         2.153371                0
# ...         ...              ...              ...
# 499990   251.47         0.576678                0
# 499991   178.12         0.408470                0
# 499992    95.21         0.472370                0
# 499993   251.47         0.576678                0
# ...

# %%
# Exportação do Modelo 2 - Classificação - Preços fora do Padrão
import joblib
joblib.dump(kmeans, r"datasets\modelo_reglog.pkl")
# Out:
# ['datasets\\modelo_reglog.pkl']

# %%
# Exportação de dados para testes no Streamlit - Modelo Regressão Logística
X_test.to_csv(r"datasets\relog_test.csv", index=False, encoding="utf-8")

# %% [markdown]
# # FIM
